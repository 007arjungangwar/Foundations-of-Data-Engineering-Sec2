# %% [markdown]
# <a href="https://colab.research.google.com/github/007arjungangwar/Foundations-of-Data-Engineering-Sec2/blob/main/Data_Preprocessing_using_pandas_31_08_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

series=pd.Series([78, 85, 65, 90])
series
# Out:
# 0    78
# 1    85
# 2    65
# 3    90
# dtype: int64

# %%
print(series.mean())
# Out:
# 79.5

# %%
print(series.max())
# Out:
# 90

# %%
print(series.min())
# Out:
# 65

# %%
print(series.std())
# Out:
# 10.847426730181986

# %%
print(round(series.std(),2))
# Out:
# 10.85

# %% [markdown]
# # **isin**

# %%
series=pd.Series([78, 85, 65, 90])

# %%
series.isin([90])
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# dtype: bool

# %%
series.isin([65,90])
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# dtype: bool

# %%
series[series.isin([65,90])]
# Out:
# 2    65
# 3    90
# dtype: int64

# %%
data = {"Name": ["Aarav", "Diya", "Rahul"],
        "Marks": [85, 80, 70]}

df = pd.DataFrame(data)
df
# Out:
#     Name  Marks
# 0  Aarav     85
# 1   Diya     80
# 2  Rahul     70

# %%
df["Marks"].mean()
# Out:
# np.float64(78.33333333333333)

# %%
df["Marks"]>df["Marks"].mean()
# Out:
# 0     True
# 1     True
# 2    False
# Name: Marks, dtype: bool

# %%
df[df["Marks"]>df["Marks"].mean()]
# Out:
#     Name  Marks
# 0  Aarav     85
# 1   Diya     80

# %%
df[df["Marks"]==df["Marks"].max()]
# Out:
#     Name  Marks
# 0  Aarav     85

# %%
df[df["Marks"]==df["Marks"].min()]
# Out:
#     Name  Marks
# 2  Rahul     70

# %%
data = {"Name": ["Gold", "Silver", "Copper"],
        "Price": [" $85k", "$80k ", " $70k "]}

df1 = pd.DataFrame(data)
df1
# Out:
#      Name   Price
# 0    Gold    $85k
# 1  Silver   $80k
# 2  Copper   $70k

# %% [markdown]
# # **strip() , replace()**

# %%
df1["Price"]
# Out:
# 0      $85k
# 1     $80k
# 2     $70k
# Name: Price, dtype: object

# %%
df1["Price"].str.strip()
# Out:
# 0    $85k
# 1    $80k
# 2    $70k
# Name: Price, dtype: object

# %%
df1["U_Price"]=df1["Price"].str.strip()

# %%
df1
# Out:
#      Name   Price U_Price
# 0    Gold    $85k    $85k
# 1  Silver   $80k     $80k
# 2  Copper   $70k     $70k

# %%
df1["Price"]=df1["Price"].str.strip()

# %%
df1["Price"]=df1["Price"].str.strip("$")

# %%
df1
# Out:
#      Name Price U_Price
# 0    Gold   85k    $85k
# 1  Silver   80k    $80k
# 2  Copper   70k    $70k

# %%
df1["Price"]=df1["Price"].str.strip("k")

# %%
df1
# Out:
#      Name Price U_Price
# 0    Gold    85    $85k
# 1  Silver    80    $80k
# 2  Copper    70    $70k

# %% [markdown]
# replace

# %%
data = {"Name": ["Gold", "Silver", "Copper"],
        "Price": ["$85k ", " $80k", " $70k "]}

df1 = pd.DataFrame(data)
df1
# Out:
#      Name   Price
# 0    Gold   $85k
# 1  Silver    $80k
# 2  Copper   $70k

# %%
df1['Price']
# Out:
# 0     $85k
# 1      $80k
# 2     $70k
# Name: Price, dtype: object

# %%
df1['Price']=df1['Price'].str.replace("$","").str.replace("k","").str.strip()

# %%
df1
# Out:
#      Name Price
# 0    Gold    85
# 1  Silver    80
# 2  Copper    70

# %%
data = {"Name": ["Gold", "Silver", "Copper"],
        "Price": ["$85k ", " $80k", " $70k "]}

df1 = pd.DataFrame(data)
df1
# Out:
#      Name   Price
# 0    Gold   $85k
# 1  Silver    $80k
# 2  Copper   $70k

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
pd.__version__
# !pip install --upgrade pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 63.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.3
#     Uninstalling pandas-2.2.3:
#       Successfully uninstalled pandas-2.2.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.3, but you have pandas 3.0.5 which is incompatible.
# ...

# %%
pd.__version__
# Out:
# '3.0.5'

# %%
df1['Price'].str.replace({"$":"","k":""}).str.strip()
# Out:
# 0    85
# 1    80
# 2    70
# Name: Price, dtype: str

# %%
df1['Price'].str.replace({"$":"","k":""}).str.strip().astype("int")
# Out:
# 0    85
# 1    80
# 2    70
# Name: Price, dtype: int64

# %% [markdown]
# # **New DataSet**

# %%
data_dict = {
    "Name": [
        "Aarav", "Diya", "Rahul", "Priya", "Arjun", "Sneha",
        "Karan", "Ananya", "Vikram", "Meera", "Rohan", "Isha"
    ],
    "Gender": [
        "Male", "Female", "Male", "Female", "Male", "Female",
        "Male", "Female", "Male", "Female", "Male", "Female"
    ],
    "Age": [20, 21, 20, 22, 21, 20, 22, 21, 20, 22, 21, 20],
    "Department": [
        "CSE", "CSE", "ECE", "CSE", "ME", "ECE",
        "CSE", "ME", "ECE", "CSE", "ME", "ECE"
    ],
    "Attendance": [92, 85, 78, 95, 65, 88, 72, 91, 80, 96, 68, 87],
    "StudyHours": [5, 4, 3, 6, 2, 5, 3, 6, 4, 7, 2, 5],
    "Assignments": [8, 7, 6, 9, 5, 8, 7, 9, 7, 10, 5, 8],
    "Midterm": [78, 72, 65, 88, 55, 76, 62, 85, 70, 90, 58, 75],
    "Final": [85, 80, 70, 92, 60, 84, 68, 90, 75, 95, 62, 82],
    "Placement": [
        "Yes", "Yes", "No", "Yes", "No", "Yes",
        "No", "Yes", "Yes", "Yes", "No", "Yes"
    ]
}

# %%
df=pd.DataFrame(data_dict)

# %%
df.head()
# Out:
#     Name  Gender  Age Department  Attendance  StudyHours  Assignments  \
# 0  Aarav    Male   20        CSE          92           5            8
# 1   Diya  Female   21        CSE          85           4            7
# 2  Rahul    Male   20        ECE          78           3            6
# 3  Priya  Female   22        CSE          95           6            9
# 4  Arjun    Male   21         ME          65           2            5
#
#    Midterm  Final Placement
# 0       78     85       Yes
# 1       72     80       Yes
# 2       65     70        No
# 3       88     92       Yes
# 4       55     60        No

# %%
df["Attendance"].mean()
# Out:
# np.float64(83.08333333333333)

# %%
df[df["Attendance"]>df["Attendance"].mean()]
# Out:
#       Name  Gender  Age Department  Attendance  StudyHours  Assignments  \
# 0    Aarav    Male   20        CSE          92           5            8
# 1     Diya  Female   21        CSE          85           4            7
# 3    Priya  Female   22        CSE          95           6            9
# 5    Sneha  Female   20        ECE          88           5            8
# 7   Ananya  Female   21         ME          91           6            9
# 9    Meera  Female   22        CSE          96           7           10
# 11    Isha  Female   20        ECE          87           5            8
#
#     Midterm  Final Placement
# 0        78     85       Yes
# 1        72     80       Yes
# 3        88     92       Yes
# 5        76     84       Yes
# 7        85     90       Yes
# 9        90     95       Yes
# 11       75     82       Yes

# %%
df[df["Attendance"]>75]
# Out:
#       Name  Gender  Age Department  Attendance  StudyHours  Assignments  \
# 0    Aarav    Male   20        CSE          92           5            8
# 1     Diya  Female   21        CSE          85           4            7
# 2    Rahul    Male   20        ECE          78           3            6
# 3    Priya  Female   22        CSE          95           6            9
# 5    Sneha  Female   20        ECE          88           5            8
# 7   Ananya  Female   21         ME          91           6            9
# 8   Vikram    Male   20        ECE          80           4            7
# 9    Meera  Female   22        CSE          96           7           10
# 11    Isha  Female   20        ECE          87           5            8
#
#     Midterm  Final Placement
# 0        78     85       Yes
# 1        72     80       Yes
# 2        65     70        No
# 3        88     92       Yes
# 5        76     84       Yes
# 7        85     90       Yes
# 8        70     75       Yes
# ...

# %%
df[df["StudyHours"]>5]
# Out:
#      Name  Gender  Age Department  Attendance  StudyHours  Assignments  \
# 3   Priya  Female   22        CSE          95           6            9
# 7  Ananya  Female   21         ME          91           6            9
# 9   Meera  Female   22        CSE          96           7           10
#
#    Midterm  Final Placement
# 3       88     92       Yes
# 7       85     90       Yes
# 9       90     95       Yes

# %% [markdown]
# .loc

# %%
df.head()
# Out:
#     Name  Gender  Age Department  Attendance  StudyHours  Assignments  \
# 0  Aarav    Male   20        CSE          92           5            8
# 1   Diya  Female   21        CSE          85           4            7
# 2  Rahul    Male   20        ECE          78           3            6
# 3  Priya  Female   22        CSE          95           6            9
# 4  Arjun    Male   21         ME          65           2            5
#
#    Midterm  Final Placement
# 0       78     85       Yes
# 1       72     80       Yes
# 2       65     70        No
# 3       88     92       Yes
# 4       55     60        No

# %%
df.loc[4]
# Out:
# Name           Arjun
# Gender          Male
# Age               21
# Department        ME
# Attendance        65
# StudyHours         2
# Assignments        5
# Midterm           55
# Final             60
# Placement         No
# Name: 4, dtype: object

# %%
df.loc[[4,5]]
# Out:
#     Name  Gender  Age Department  Attendance  StudyHours  Assignments  \
# 4  Arjun    Male   21         ME          65           2            5
# 5  Sneha  Female   20        ECE          88           5            8
#
#    Midterm  Final Placement
# 4       55     60        No
# 5       76     84       Yes

# %%
df.loc[5:]
# Out:
#       Name  Gender  Age Department  Attendance  StudyHours  Assignments  \
# 5    Sneha  Female   20        ECE          88           5            8
# 6    Karan    Male   22        CSE          72           3            7
# 7   Ananya  Female   21         ME          91           6            9
# 8   Vikram    Male   20        ECE          80           4            7
# 9    Meera  Female   22        CSE          96           7           10
# 10   Rohan    Male   21         ME          68           2            5
# 11    Isha  Female   20        ECE          87           5            8
#
#     Midterm  Final Placement
# 5        76     84       Yes
# 6        62     68        No
# 7        85     90       Yes
# 8        70     75       Yes
# 9        90     95       Yes
# 10       58     62        No
# 11       75     82       Yes

# %%
df.loc[5,"Department"]
# Out:
# 'ECE'

# %%
df.loc[10,"Assignments"]
# Out:
# np.int64(5)

# %%
print(df.loc[10,"Midterm"])
print(df.loc[10,"Final"])
print(df.loc[10,"Midterm"])
# Out:
# 58
# 62
# 58

# %%
df.loc[2, "StudyHours"] = None

# %%
df
# Out:
#       Name  Gender  Age Department  Attendance  StudyHours  Assignments  \
# 0    Aarav    Male   20        CSE          92         5.0            8
# 1     Diya  Female   21        CSE          85         4.0            7
# 2    Rahul    Male   20        ECE          78         NaN            6
# 3    Priya  Female   22        CSE          95         6.0            9
# 4    Arjun    Male   21         ME          65         2.0            5
# 5    Sneha  Female   20        ECE          88         5.0            8
# 6    Karan    Male   22        CSE          72         3.0            7
# 7   Ananya  Female   21         ME          91         6.0            9
# 8   Vikram    Male   20        ECE          80         4.0            7
# 9    Meera  Female   22        CSE          96         7.0           10
# 10   Rohan    Male   21         ME          68         2.0            5
# 11    Isha  Female   20        ECE          87         5.0            8
#
#     Midterm  Final Placement
# ...

# %%
df.loc[9, "Final"] = None

# %%
df
# Out:
#       Name  Gender  Age Department  Attendance  StudyHours  Assignments  \
# 0    Aarav    Male   20        CSE          92         5.0            8
# 1     Diya  Female   21        CSE          85         4.0            7
# 2    Rahul    Male   20        ECE          78         NaN            6
# 3    Priya  Female   22        CSE          95         6.0            9
# 4    Arjun    Male   21         ME          65         2.0            5
# 5    Sneha  Female   20        ECE          88         5.0            8
# 6    Karan    Male   22        CSE          72         3.0            7
# 7   Ananya  Female   21         ME          91         6.0            9
# 8   Vikram    Male   20        ECE          80         4.0            7
# 9    Meera  Female   22        CSE          96         7.0           10
# 10   Rohan    Male   21         ME          68         2.0            5
# 11    Isha  Female   20        ECE          87         5.0            8
#
#     Midterm  Final Placement
# ...

# %%
df.loc[9, "Name"] = "Advika"

# %%
df
# Out:
#       Name  Gender  Age Department  Attendance  StudyHours  Assignments  \
# 0    Aarav    Male   20        CSE          92         5.0            8
# 1     Diya  Female   21        CSE          85         4.0            7
# 2    Rahul    Male   20        ECE          78         NaN            6
# 3    Priya  Female   22        CSE          95         6.0            9
# 4    Arjun    Male   21         ME          65         2.0            5
# 5    Sneha  Female   20        ECE          88         5.0            8
# 6    Karan    Male   22        CSE          72         3.0            7
# 7   Ananya  Female   21         ME          91         6.0            9
# 8   Vikram    Male   20        ECE          80         4.0            7
# 9   Advika  Female   22        CSE          96         7.0           10
# 10   Rohan    Male   21         ME          68         2.0            5
# 11    Isha  Female   20        ECE          87         5.0            8
#
#     Midterm  Final Placement
# ...

# %%
df.iloc[[9]]
# Out:
#      Name  Gender  Age Department  Attendance  StudyHours  Assignments  \
# 9  Advika  Female   22        CSE          96         7.0           10
#
#    Midterm  Final Placement
# 9       90    NaN       Yes

# %%
df = pd.concat([df, df.iloc[[9]]], ignore_index=True)

# %%
df
# Out:
#       Name  Gender  Age Department  Attendance  StudyHours  Assignments  \
# 0    Aarav    Male   20        CSE          92         5.0            8
# 1     Diya  Female   21        CSE          85         4.0            7
# 2    Rahul    Male   20        ECE          78         NaN            6
# 3    Priya  Female   22        CSE          95         6.0            9
# 4    Arjun    Male   21         ME          65         2.0            5
# 5    Sneha  Female   20        ECE          88         5.0            8
# 6    Karan    Male   22        CSE          72         3.0            7
# 7   Ananya  Female   21         ME          91         6.0            9
# 8   Vikram    Male   20        ECE          80         4.0            7
# 9   Advika  Female   22        CSE          96         7.0           10
# 10   Rohan    Male   21         ME          68         2.0            5
# 11    Isha  Female   20        ECE          87         5.0            8
# ...

# %%
df.loc[9, "Name"] = "Meera"

# %%
df
# Out:
#       Name  Gender  Age Department  Attendance  StudyHours  Assignments  \
# 0    Aarav    Male   20        CSE          92         5.0            8
# 1     Diya  Female   21        CSE          85         4.0            7
# 2    Rahul    Male   20        ECE          78         NaN            6
# 3    Priya  Female   22        CSE          95         6.0            9
# 4    Arjun    Male   21         ME          65         2.0            5
# 5    Sneha  Female   20        ECE          88         5.0            8
# 6    Karan    Male   22        CSE          72         3.0            7
# 7   Ananya  Female   21         ME          91         6.0            9
# 8   Vikram    Male   20        ECE          80         4.0            7
# 9    Meera  Female   22        CSE          96         7.0           10
# 10   Rohan    Male   21         ME          68         2.0            5
# 11    Isha  Female   20        ECE          87         5.0            8
# ...

# %%
df.isnull().sum()
# Out:
# Name           0
# Gender         0
# Age            0
# Department     0
# Attendance     0
# StudyHours     1
# Assignments    0
# Midterm        0
# Final          2
# Placement      0
# dtype: int64

# %%
df.dtypes
# Out:
# Name               str
# Gender             str
# Age              int64
# Department         str
# Attendance       int64
# StudyHours     float64
# Assignments      int64
# Midterm          int64
# Final          float64
# Placement          str
# dtype: object

# %%
df[df["Department"]=="CSE"]
# Out:
#       Name  Gender  Age Department  Attendance  StudyHours  Assignments  \
# 0    Aarav    Male   20        CSE          92         5.0            8
# 1     Diya  Female   21        CSE          85         4.0            7
# 3    Priya  Female   22        CSE          95         6.0            9
# 6    Karan    Male   22        CSE          72         3.0            7
# 9    Meera  Female   22        CSE          96         7.0           10
# 12  Advika  Female   22        CSE          96         7.0           10
#
#     Midterm  Final Placement
# 0        78   85.0       Yes
# 1        72   80.0       Yes
# 3        88   92.0       Yes
# 6        62   68.0        No
# 9        90    NaN       Yes
# 12       90    NaN       Yes

# %%
df[(df["Attendance"]>75) & (df["Final"]>80)]
# Out:
#       Name  Gender  Age Department  Attendance  StudyHours  Assignments  \
# 0    Aarav    Male   20        CSE          92         5.0            8
# 3    Priya  Female   22        CSE          95         6.0            9
# 5    Sneha  Female   20        ECE          88         5.0            8
# 7   Ananya  Female   21         ME          91         6.0            9
# 11    Isha  Female   20        ECE          87         5.0            8
#
#     Midterm  Final Placement
# 0        78   85.0       Yes
# 3        88   92.0       Yes
# 5        76   84.0       Yes
# 7        85   90.0       Yes
# 11       75   82.0       Yes

# %%
df[(df["Department"]=="CSE") & (df["Final"]>=85)]
# Out:
#     Name  Gender  Age Department  Attendance  StudyHours  Assignments  \
# 0  Aarav    Male   20        CSE          92         5.0            8
# 3  Priya  Female   22        CSE          95         6.0            9
#
#    Midterm  Final Placement
# 0       78   85.0       Yes
# 3       88   92.0       Yes

# %%
df.loc[2,"Final"]=None
df.loc[10,"Attendance"]=None
df.loc[10,"Assignments"]=None
df
# Out:
#       Name  Gender  Age Department  Attendance  StudyHours  Assignments  \
# 0    Aarav    Male   20        CSE        92.0         5.0          8.0
# 1     Diya  Female   21        CSE        85.0         4.0          7.0
# 2    Rahul    Male   20        ECE        78.0         NaN          6.0
# 3    Priya  Female   22        CSE        95.0         6.0          9.0
# 4    Arjun    Male   21         ME        65.0         2.0          5.0
# 5    Sneha  Female   20        ECE        88.0         5.0          8.0
# 6    Karan    Male   22        CSE        72.0         3.0          7.0
# 7   Ananya  Female   21         ME        91.0         6.0          9.0
# 8   Vikram    Male   20        ECE        80.0         4.0          7.0
# 9    Meera  Female   22        CSE        96.0         7.0         10.0
# 10   Rohan    Male   21         ME         NaN         2.0          NaN
# 11    Isha  Female   20        ECE        87.0         5.0          8.0
# ...

# %%
df.isnull().sum()
# Out:
# Name           0
# Gender         0
# Age            0
# Department     0
# Attendance     1
# StudyHours     1
# Assignments    1
# Midterm        0
# Final          3
# Placement      0
# dtype: int64

# %%
print(df.shape)
df.drop_duplicates()
# Out:
# (13, 10)
#       Name  Gender  Age Department  Attendance  StudyHours  Assignments  \
# 0    Aarav    Male   20        CSE        92.0         5.0          8.0
# 1     Diya  Female   21        CSE        85.0         4.0          7.0
# 2    Rahul    Male   20        ECE        78.0         NaN          6.0
# 3    Priya  Female   22        CSE        95.0         6.0          9.0
# 4    Arjun    Male   21         ME        65.0         2.0          5.0
# 5    Sneha  Female   20        ECE        88.0         5.0          8.0
# 6    Karan    Male   22        CSE        72.0         3.0          7.0
# 7   Ananya  Female   21         ME        91.0         6.0          9.0
# 8   Vikram    Male   20        ECE        80.0         4.0          7.0
# 9    Meera  Female   22        CSE        96.0         7.0         10.0
# 10   Rohan    Male   21         ME         NaN         2.0          NaN
# 11    Isha  Female   20        ECE        87.0         5.0          8.0
# ...

# %%
print(df.shape)
# Out:
# (13, 10)

# %%
df.loc[[7]]
# Out:
#      Name  Gender  Age Department  Attendance  StudyHours  Assignments  \
# 7  Ananya  Female   21         ME        91.0         6.0          9.0
#
#    Midterm  Final Placement
# 7       85   90.0       Yes

# %%
duplicate_df=pd.concat([df,df.loc[[7]]],ignore_index=True)
duplicate_df
# Out:
#       Name  Gender  Age Department  Attendance  StudyHours  Assignments  \
# 0    Aarav    Male   20        CSE        92.0         5.0          8.0
# 1     Diya  Female   21        CSE        85.0         4.0          7.0
# 2    Rahul    Male   20        ECE        78.0         NaN          6.0
# 3    Priya  Female   22        CSE        95.0         6.0          9.0
# 4    Arjun    Male   21         ME        65.0         2.0          5.0
# 5    Sneha  Female   20        ECE        88.0         5.0          8.0
# 6    Karan    Male   22        CSE        72.0         3.0          7.0
# 7   Ananya  Female   21         ME        91.0         6.0          9.0
# 8   Vikram    Male   20        ECE        80.0         4.0          7.0
# 9    Meera  Female   22        CSE        96.0         7.0         10.0
# 10   Rohan    Male   21         ME         NaN         2.0          NaN
# 11    Isha  Female   20        ECE        87.0         5.0          8.0
# ...

# %% [markdown]
# Calculate the percentage of missing values:

# %%
df.isnull().sum()
# Out:
# Name           0
# Gender         0
# Age            0
# Department     0
# Attendance     1
# StudyHours     1
# Assignments    1
# Midterm        0
# Final          3
# Placement      0
# dtype: int64

# %%
df.isnull().mean() * 100
# Out:
# Name            0.000000
# Gender          0.000000
# Age             0.000000
# Department      0.000000
# Attendance      7.692308
# StudyHours      7.692308
# Assignments     7.692308
# Midterm         0.000000
# Final          23.076923
# Placement       0.000000
# dtype: float64

# %% [markdown]
# Handling Missing Values

# %%
df["Attendance"].mean()
# Out:
# np.float64(85.41666666666667)

# %%
df["Attendance"] = df["Attendance"].fillna(df["Attendance"].mean())
df
# Out:
# C:\Users\Arjun Singh\AppData\Local\Temp\ipykernel_23792\3342906491.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["Attendance"]=df["Attendance"].fillna(df["Attendance"].mean(),inplace=True)
#       Name  Gender  Age Department  Attendance  StudyHours  Assignments  \
# ...

# %%
df["Final"] = df["Final"].fillna(df["Final"].max())
df
# Out:
# C:\Users\Arjun Singh\AppData\Local\Temp\ipykernel_23792\706972356.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["Final"]=df["Final"].fillna(df["Final"].max(),inplace=True)
#       Name  Gender  Age Department  Attendance  StudyHours  Assignments  \
# ...

# %%
df["Final"]=df["Final"].fillna(df["Final"].min())
df["Attendance"]=df["Attendance"].fillna(df["Attendance"].min())
df
# Out:
#       Name  Gender  Age Department  Attendance  StudyHours  Assignments  \
# 0    Aarav    Male   20        CSE   92.000000         5.0          8.0
# 1     Diya  Female   21        CSE   85.000000         4.0          7.0
# 2    Rahul    Male   20        ECE   78.000000         NaN          6.0
# 3    Priya  Female   22        CSE   95.000000         6.0          9.0
# 4    Arjun    Male   21         ME   65.000000         2.0          5.0
# 5    Sneha  Female   20        ECE   88.000000         5.0          8.0
# 6    Karan    Male   22        CSE   72.000000         3.0          7.0
# 7   Ananya  Female   21         ME   91.000000         6.0          9.0
# 8   Vikram    Male   20        ECE   80.000000         4.0          7.0
# 9    Meera  Female   22        CSE   96.000000         7.0         10.0
# 10   Rohan    Male   21         ME   85.416667         2.0          NaN
# 11    Isha  Female   20        ECE   87.000000         5.0          8.0
# ...

# %%
df2=df[["Name","Gender","Final"]].copy()
df2
# Out:
#       Name  Gender  Final
# 0    Aarav    Male   85.0
# 1     Diya  Female   80.0
# 2    Rahul    Male   92.0
# 3    Priya  Female   92.0
# 4    Arjun    Male   60.0
# 5    Sneha  Female   84.0
# 6    Karan    Male   68.0
# 7   Ananya  Female   90.0
# 8   Vikram    Male   75.0
# 9    Meera  Female   92.0
# 10   Rohan    Male   62.0
# 11    Isha  Female   82.0
# 12  Advika  Female   92.0

# %%
df2.loc[4:]
# Out:
#       Name  Gender  Final
# 4    Arjun    Male   60.0
# 5    Sneha  Female   84.0
# 6    Karan    Male   68.0
# 7   Ananya  Female   90.0
# 8   Vikram    Male   75.0
# 9    Meera  Female   92.0
# 10   Rohan    Male   62.0
# 11    Isha  Female   82.0
# 12  Advika  Female   92.0

# %%
df2.loc[:5]
# Out:
#     Name  Gender  Final
# 0  Aarav    Male   85.0
# 1   Diya  Female   80.0
# 2  Rahul    Male   92.0
# 3  Priya  Female   92.0
# 4  Arjun    Male   60.0
# 5  Sneha  Female   84.0

# %%
df2.loc[1:5]
# Out:
#     Name  Gender  Final
# 1   Diya  Female   80.0
# 2  Rahul    Male   92.0
# 3  Priya  Female   92.0
# 4  Arjun    Male   60.0
# 5  Sneha  Female   84.0

# %%
df["TotalMarks"] = df["Midterm"] + df["Final"]
df
# Out:
#       Name  Gender  Age Department  Attendance  StudyHours  Assignments  \
# 0    Aarav    Male   20        CSE   92.000000         5.0          8.0
# 1     Diya  Female   21        CSE   85.000000         4.0          7.0
# 2    Rahul    Male   20        ECE   78.000000         NaN          6.0
# 3    Priya  Female   22        CSE   95.000000         6.0          9.0
# 4    Arjun    Male   21         ME   65.000000         2.0          5.0
# 5    Sneha  Female   20        ECE   88.000000         5.0          8.0
# 6    Karan    Male   22        CSE   72.000000         3.0          7.0
# 7   Ananya  Female   21         ME   91.000000         6.0          9.0
# 8   Vikram    Male   20        ECE   80.000000         4.0          7.0
# 9    Meera  Female   22        CSE   96.000000         7.0         10.0
# 10   Rohan    Male   21         ME   85.416667         2.0          NaN
# 11    Isha  Female   20        ECE   87.000000         5.0          8.0
# ...
