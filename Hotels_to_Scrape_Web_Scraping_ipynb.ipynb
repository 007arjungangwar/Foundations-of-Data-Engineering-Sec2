# %% [markdown]
# <a href="https://colab.research.google.com/github/007arjungangwar/Foundations-of-Data-Engineering-Sec2/blob/main/Hotels_to_Scrape_Web_Scraping_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [link text](https://www.oyorooms.com/hotels-in-chennai/?gad_campaignid=1701551904&gad_source=1&gclid=Cj0KCQjwv4XUBhDBARIsAE6bQURyjnNdPXAQkugbgFSbiyqyn-9ObIc0VOFF0JmlsgFXGMXSJp5uKCIaAnzIEALw_wcB&utm_adgroup=143959616297&utm_campaign=India_SEM_Brand_generic&utm_campaignid=1701551904&utm_content=751298002022&utm_device=c&utm_keyword=oyo&utm_medium=cpc&utm_source=google)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
page_url="https://www.oyorooms.com/hotels-in-chennai/?gad_campaignid=1701551904&gad_source=1&gclid=Cj0KCQjwv4XUBhDBARIsAE6bQURyjnNdPXAQkugbgFSbiyqyn-9ObIc0VOFF0JmlsgFXGMXSJp5uKCIaAnzIEALw_wcB&utm_adgroup=143959616297&utm_campaign=India_SEM_Brand_generic&utm_campaignid=1701551904&utm_content=751298002022&utm_device=c&utm_keyword=oyo&utm_medium=cpc&utm_source=google"

# %%
# 3. Send HTTP request
response = requests.get(page_url)
print(f"Status Code: {response.status_code}")
# Out:
# Status Code: 200

# %%
response.content
# Out:
# b'<!DOCTYPE html>\n<html>\n<head>\n    <title></title>\n    <meta charset="UTF-8">\n</head>\n<body>\n</body>\n</html>\n'

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <title></title>
# <meta charset="utf-8"/>
# </head>
# <body>
# </body>
# </html>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#   </title>
#   <meta charset="utf-8"/>
#  </head>
#  <body>
#  </body>
# </html>

# %%
print(soup.title)
# Out:
# <title></title>

# %%
page_url="https://www.oyorooms.com/hotels-in-chennai/?gad_campaignid=1701551904&gad_source=1&gclid=Cj0KCQjwv4XUBhDBARIsAE6bQURyjnNdPXAQkugbgFSbiyqyn-9ObIc0VOFF0JmlsgFXGMXSJp5uKCIaAnzIEALw_wcB&utm_adgroup=143959616297&utm_campaign=India_SEM_Brand_generic&utm_campaignid=1701551904&utm_content=751298002022&utm_device=c&utm_keyword=oyo&utm_medium=cpc&utm_source=google"

# %%
# 1. Send request
response = requests.get(page_url,headers={"User-Agent": "Mozilla/5.0"})

print("Status Code:", response.status_code)
# Out:
# Status Code: 200

# %%
print("Status Code:", response.status_code)
print("Page Length:", len(response.text))
# Out:
# Status Code: 200
# Page Length: 761632

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge; chrome=1" httpequiv="x-ua-compatible"/>
#   <meta content="f4uoIv4kokZmLBB_APXVlufTrtP7bTJCUIOF0EXeObM" name="google-site-verification"/>
#   <script type="text/javascript">
#    window.renderingSource='server'
#         var host = window.location.hostname;
#         if (!String.prototype.endsWith) {
# 	        String.prototype.endsWith = function(search, this_len) {
# 		        if (this_len === undefined || this_len > this.length) {
# 			        this_len = this.length;
# 		        }
# 	      	  return this.substring(this_len - search.length, this_len) === search;
# 	        };
#         }
#         // if (! (host.endsWith("oyorooms.com") || host.endsWith("oyorooms.ms") || host.endsWith("oyohotels.co.jp") || host.endsWith("hotelesoyo.com") || host.endsWith("oyohotels.com") || host.endsWith("belvilla.co.in") || host.endsWith("oyorooms.io")) && host.indexOf('localhost') < 0){
# ...

# %%
print(soup.title)
# Out:
# <title data-react-helmet="true">Hotels in Chennai Starting @ ₹680 - Upto 78% OFF on 107 Chennai Hotels</title>

# %%
soup.find_all('p')
# Out:
# []

# %%
soup.find_all('h3')
# Out:
# [<h3 class="listingHotelDescription__hotelName d-textEllipsis" itemprop="name" title="Super Collection O Kundrathur Near Murugan Temple">Super Collection O Kundrathur Near Murugan Temple</h3>,
#  <h3 class="listingHotelDescription__hotelName d-textEllipsis" itemprop="name" title="Collection O Shriram Gateway Road Chennai">Collection O Shriram Gateway Road Chennai</h3>,
#  <h3 class="listingHotelDescription__hotelName d-textEllipsis" itemprop="name" title="Super Townhouse IT Chennai Formerly Radha Jayam Residency">Super Townhouse IT Chennai Formerly Radha Jayam Residency</h3>,
#  <h3 class="listingHotelDescription__hotelName d-textEllipsis" itemprop="name" title="Hotel O Nanmangalam Forestview Chennai Formerly Dap Apartment">Hotel O Nanmangalam Forestview Chennai Formerly Dap Apartment</h3>,
# ...

# %%
soup.find_all('div')
# Out:
# [<div id="root" style="height:100vh;"><style data-emotion-c="1acbpvw r9lts4 g49e0i 1iupfd9 s2hsb0 162c9d0 8ijf8a p2g0oj jj695s 1x32axc xotlao 1t05q14 mk5v0g zi3trd bxjamc g7fw8n">@-webkit-keyframes animation-1acbpvw{0%{opacity:0;}100%{opacity:1;}}@keyframes animation-1acbpvw{0%{opacity:0;}100%{opacity:1;}}@-webkit-keyframes animation-r9lts4{0%{background-position:-350px 0;}100%{background-position:350px 0;}}@keyframes animation-r9lts4{0%{background-position:-350px 0;}100%{background-position:350px 0;}}@-webkit-keyframes animation-g49e0i{from{-webkit-transform:translate3d(0,-100 %,0);-ms-transform:translate3d(0,-100 %,0);transform:translate3d(0,-100 %,0);visibility:visible;}to{-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}}@keyframes animation-g49e0i{from{-webkit-transform:translate3d(0,-100 %,0);-ms-transform:translate3d(0,-100 %,0);transform:translate3d(0,-100 %,0);visibility:visible;}to{-webkit-transform:translate3d(0,0,0);-ms-t
# ...

# %%
# 4. Find property cards
hotels = soup.find_all('div')
print(f'There are: {len(hotels)} hotels found.')
# Out:
# There are: 2656 hotels found.

# %%
hotels=soup.find_all('div',class_="oyo-cell--12-col oyo-cell--8-col-tablet oyo-cell--4-col-phone")

# %%
hotels
# Out:
# [<div class="oyo-cell--12-col oyo-cell--8-col-tablet oyo-cell--4-col-phone"><div class="oyo-row oyo-row--no-spacing hotelCardListing"><div class="hotelCardListing__imgCardWrapper"><div class="oyo-row oyo-row--no-spacing listingImageCard"><div class="oyo-cell--10-col listingImageCard__carousel"><div class="slick-slider slick-fadeinSlideshow slick-initialized" dir="ltr"><button class="slick-arrow slick-prev" data-role="none" style="display: block;" type="button"> Previous</button><div class="slick-list"><div class="slick-track" style="width: 8300%; left: -100%;"><div aria-hidden="true" class="slick-slide slick-cloned" data-index="-1" style="width: 1.2048192771084338%;" tabindex="-1"></div><div aria-hidden="false" class="slick-slide slick-active slick-current" data-index="0" style="outline: none; width: 1.2048192771084338%;" tabindex="-1"><div><style data-emotion-c="ahj8kj">.c-ahj8kj{color:rgba(0,0,0,0.54);background:#f3f5f7;height:100%;width:100%;background:#f3f5f7;-webkit-animation:no
# ...

# %%
len(hotels)
# Out:
# 20

# %%
hotels=soup.find_all('div',class_="oyo-row oyo-row--no-spacing hotelCardListing")

# %%
hotels
# Out:
# [<div class="oyo-row oyo-row--no-spacing hotelCardListing"><div class="hotelCardListing__imgCardWrapper"><div class="oyo-row oyo-row--no-spacing listingImageCard"><div class="oyo-cell--10-col listingImageCard__carousel"><div class="slick-slider slick-fadeinSlideshow slick-initialized" dir="ltr"><button class="slick-arrow slick-prev" data-role="none" style="display: block;" type="button"> Previous</button><div class="slick-list"><div class="slick-track" style="width: 8300%; left: -100%;"><div aria-hidden="true" class="slick-slide slick-cloned" data-index="-1" style="width: 1.2048192771084338%;" tabindex="-1"></div><div aria-hidden="false" class="slick-slide slick-active slick-current" data-index="0" style="outline: none; width: 1.2048192771084338%;" tabindex="-1"><div><style data-emotion-c="ahj8kj">.c-ahj8kj{color:rgba(0,0,0,0.54);background:#f3f5f7;height:100%;width:100%;background:#f3f5f7;-webkit-animation:none;animation:none;position:relative;z-index:0;}.c-ahj8kj:after{content:'';p
# ...

# %%
len(hotels)
# Out:
# 20

# %%
hotel1=soup.find('div',class_="oyo-row oyo-row--no-spacing hotelCardListing")

# %%
print(hotel1.prettify())
# Out:
# <div class="oyo-row oyo-row--no-spacing hotelCardListing">
#  <div class="hotelCardListing__imgCardWrapper">
#   <div class="oyo-row oyo-row--no-spacing listingImageCard">
#    <div class="oyo-cell--10-col listingImageCard__carousel">
#     <div class="slick-slider slick-fadeinSlideshow slick-initialized" dir="ltr">
#      <button class="slick-arrow slick-prev" data-role="none" style="display: block;" type="button">
#       Previous
#      </button>
#      <div class="slick-list">
#       <div class="slick-track" style="width: 8300%; left: -100%;">
#        <div aria-hidden="true" class="slick-slide slick-cloned" data-index="-1" style="width: 1.2048192771084338%;" tabindex="-1">
#        </div>
#        <div aria-hidden="false" class="slick-slide slick-active slick-current" data-index="0" style="outline: none; width: 1.2048192771084338%;" tabindex="-1">
#         <div>
#          <style data-emotion-c="ahj8kj">
# ...

# %%
len(hotel1)
# Out:
# 2

# %%
title = hotel1.h3["title"]
title
# Out:
# 'Super Collection O Kundrathur Near Murugan Temple'

# %%
Address=hotel1.find('span',class_="u-line--clamp-2")
Address
# Out:
# <span class="u-line--clamp-2" itemprop="streetAddress" style="box-orient: vertical; -webkit-box-orient: vertical;" title="Manancherry, Chennai">Manancherry, Chennai</span>

# %%
Address=hotel1.find('span',class_="u-line--clamp-2")["title"]
Address
# Out:
# 'Manancherry, Chennai'

# %%
num_rating=hotel1.find('span',class_="hotelRating__ratingSummary hotelRating__rating--clickable").text
num_rating
# Out:
# '(491 Ratings)'

# %%
star_rating=hotel1.find('span',class_="is-fontBold hotelRating__rating hotelRating__rating--verygood hotelRating__rating--clickable")
star_rating

# %%
price=hotel1.find('span',class_="listingPrice__finalPrice listingPrice__finalPrice--black").text
price
# Out:
# '₹972'

# %%
# Extract relative src attribute
img_src = hotel1.find("div", class_="c-ahj8kj").find("img")["src"]
img_src
# Out:
# 'https://images.oyoroomscdn.com/uploads/hotel_image/295423/medium/npevqopnsahc.jpg'

# %%
all_hotels_data = []
for hotel in hotels:
    title = hotel.h3["title"]
    Address=hotel.find('span',class_="u-line--clamp-2")["title"]
    num_rating=hotel.find('span',class_="hotelRating__ratingSummary hotelRating__rating--clickable").text
    star_rating=hotel.find('span',class_="is-fontBold hotelRating__rating hotelRating__rating--verygood hotelRating__rating--clickable")
    price=hotel.find('span',class_="listingPrice__finalPrice listingPrice__finalPrice--black").text
    img_src = hotel.find("div", class_="c-ahj8kj").find("img")["src"]


    all_hotels_data.append({
        "title": title,
        "Address":Address,
        "num_rating":num_rating,
        "star_rating":star_rating,
        "price": price,
        #"img_src": img_src

    })
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1553/2990593952.py in <cell line: 0>()
#       1 all_hotels_data = []
#       2 for hotel in hotels:
# ----> 3     title = hotel.h3["title"]
#       4     Address=hotel.find('span',class_="u-line--clamp-2")["title"]
#       5     num_rating=hotel.find('span',class_="hotelRating__ratingSummary hotelRating__rating--clickable").text
#
# TypeError: 'NoneType' object is not subscriptable

# %%
all_hotels_data
# Out:
# [{'title': 'Super Collection O Kundrathur Near Murugan Temple',
#   'Address': 'Manancherry, Chennai',
#   'num_rating': '(491 Ratings)',
#   'star_rating': <span class="is-fontBold hotelRating__rating hotelRating__rating--verygood hotelRating__rating--clickable"><span>4.4</span><span class="hotelRating__star"></span> </span>,
#   'price': '₹972'},
#  {'title': 'Super Collection O Kundrathur Near Murugan Temple',
#   'Address': 'Manancherry, Chennai',
#   'num_rating': '(491 Ratings)',
#   'star_rating': <span class="is-fontBold hotelRating__rating hotelRating__rating--verygood hotelRating__rating--clickable"><span>4.4</span><span class="hotelRating__star"></span> </span>,
#   'price': '₹972'}]

# %% [markdown]
# # **Remove errors**

# %%
all_hotels_data = []
for hotel in hotels:
    try:
        title = hotel.h3["title"]
    except:
        title = None
    try:
        Address=hotel.find('span',class_="u-line--clamp-2")["title"]
    except:
        Address=None
    try:
        num_rating=hotel.find('span',class_="hotelRating__ratingSummary hotelRating__rating--clickable").text
    except:
        num_rating=None
    try:
        star_rating=hotel.find('span',class_="is-fontBold hotelRating__rating hotelRating__rating--verygood hotelRating__rating--clickable")
    except:
        star_rating=None
    try:
        price=hotel.find('span',class_="listingPrice__finalPrice listingPrice__finalPrice--black").text
    except:
        price=None
    try:
        img_src = hotel.find("div", class_="c-ahj8kj").find("img")["src"]
    except:
        img_src=None

    all_hotels_data.append({
        "title": title,
        "Address":Address,
        "num_rating":num_rating,
        "star_rating":star_rating,
        "price": price,
        "img_src": img_src

    })

# %%
all_hotels_data
# Out:
# [{'title': 'Super Collection O Kundrathur Near Murugan Temple',
#   'Address': 'Manancherry, Chennai',
#   'num_rating': '(491 Ratings)',
#   'star_rating': <span class="is-fontBold hotelRating__rating hotelRating__rating--verygood hotelRating__rating--clickable"><span>4.4</span><span class="hotelRating__star"></span> </span>,
#   'price': '₹972',
#   'img_src': 'https://images.oyoroomscdn.com/uploads/hotel_image/295423/medium/npevqopnsahc.jpg'},
#  {'title': 'Super Collection O Kundrathur Near Murugan Temple',
#   'Address': 'Manancherry, Chennai',
#   'num_rating': '(491 Ratings)',
#   'star_rating': <span class="is-fontBold hotelRating__rating hotelRating__rating--verygood hotelRating__rating--clickable"><span>4.4</span><span class="hotelRating__star"></span> </span>,
#   'price': '₹972',
#   'img_src': 'https://images.oyoroomscdn.com/uploads/hotel_image/295423/medium/npevqopnsahc.jpg'},
#  {'title': None,
#   'Address': None,
#   'num_rating': None,
#   'star_rating': None,
# ...

# %%
len(all_hotels_data)
# Out:
# 2656

# %% [markdown]
# # **2nd: Go inside main Container To fetch the data**

# %%
hotels_card=soup.find_all('div',class_="oyo-row oyo-row--no-spacing ListingHotelCardWrapper")

# %%
all_hotels_data = []
for item in hotels_card:
    hotels=soup.find_all('div',class_="oyo-cell--12-col oyo-cell--8-col-tablet oyo-cell--4-col-phone")
    for hotel in hotels:
        title = hotel.h3["title"]
        Address=hotel.find('span',class_="u-line--clamp-2")["title"]
        num_rating=hotel.find('span',class_="hotelRating__ratingSummary hotelRating__rating--clickable").text
        star_rating=hotel.find('span',class_="is-fontBold hotelRating__rating hotelRating__rating--verygood hotelRating__rating--clickable")
        price=hotel.find('span',class_="listingPrice__finalPrice listingPrice__finalPrice--black").text
        #img_src = hotel.find("div", class_="c-ahj8kj").find("img")["src"]

        all_hotels_data.append({
            "title": title,
            "Address":Address,
            "num_rating":num_rating,
            "star_rating":star_rating,
            "price": price,
            #"img_src": img_src

        })

# %%
all_hotels_data
# Out:
# [{'title': 'Super Collection O Kundrathur Near Murugan Temple',
#   'Address': 'Manancherry, Chennai',
#   'num_rating': '(491 Ratings)',
#   'star_rating': None,
#   'price': '₹972'},
#  {'title': 'Collection O Shriram Gateway Road Chennai',
#   'Address': 'Kancheepuram, Chennai',
#   'num_rating': '(1 Ratings)',
#   'star_rating': <span class="is-fontBold hotelRating__rating hotelRating__rating--verygood hotelRating__rating--clickable"><span>4.4</span><span class="hotelRating__star"></span> </span>,
#   'price': '₹771'},
#  {'title': 'Super Townhouse IT Chennai Formerly Radha Jayam Residency',
#   'Address': 'Kanchipuram, Chennai',
#   'num_rating': '(107 Ratings)',
#   'star_rating': <span class="is-fontBold hotelRating__rating hotelRating__rating--verygood hotelRating__rating--clickable"><span>4.4</span><span class="hotelRating__star"></span> </span>,
#   'price': '₹1283'},
#  {'title': 'Hotel O Nanmangalam Forestview Chennai Formerly Dap Apartment',
# ...

# %%
len(all_hotels_data)
# Out:
# 20

# %%
all_hotels_data = []
for item in hotels_card:
    hotels=soup.find_all('div',class_="oyo-cell--12-col oyo-cell--8-col-tablet oyo-cell--4-col-phone")
    for hotel in hotels:
        title = hotel.h3["title"]
        Address=hotel.find('span',class_="u-line--clamp-2")["title"]
        num_rating=hotel.find('span',class_="hotelRating__ratingSummary hotelRating__rating--clickable").text
        star_rating=hotel.find('span',class_="is-fontBold hotelRating__rating hotelRating__rating--verygood hotelRating__rating--clickable")
        price=hotel.find('span',class_="listingPrice__finalPrice listingPrice__finalPrice--black").text
        try:
            img_src = hotel.find("div", class_="c-ahj8kj").find("img")["src"]
        except:
            img_src=None

        all_hotels_data.append({
            "title": title,
            "Address":Address,
            "num_rating":num_rating,
            "star_rating":star_rating,
            "price": price,
            "img_src": img_src

        })

# %%
all_hotels_data
# Out:
# [{'title': 'Super Collection O Kundrathur Near Murugan Temple',
#   'Address': 'Manancherry, Chennai',
#   'num_rating': '(491 Ratings)',
#   'star_rating': None,
#   'price': '₹972',
#   'img_src': 'https://images.oyoroomscdn.com/uploads/hotel_image/295423/medium/npevqopnsahc.jpg'},
#  {'title': 'Collection O Shriram Gateway Road Chennai',
#   'Address': 'Kancheepuram, Chennai',
#   'num_rating': '(1 Ratings)',
#   'star_rating': <span class="is-fontBold hotelRating__rating hotelRating__rating--verygood hotelRating__rating--clickable"><span>4.4</span><span class="hotelRating__star"></span> </span>,
#   'price': '₹771',
#   'img_src': 'https://images.oyoroomscdn.com/uploads/hotel_image/378090/medium/qrfmbgnwvlry.jpg'},
#  {'title': 'Super Townhouse IT Chennai Formerly Radha Jayam Residency',
#   'Address': 'Kanchipuram, Chennai',
#   'num_rating': '(107 Ratings)',
# ...

# %%
len(all_hotels_data)
# Out:
# 20

# %% [markdown]
# # **Loop through the first 5 pages**

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

all_hotels_data = []

# Loop through the first 5 pages
for page_num in range(1, 6):
    page_url = f"https://www.oyorooms.com/hotels-in-chennai/?gad_campaignid=1701551904&gad_source={page_num}&gclid=Cj0KCQjwv4XUBhDBARIsAE6bQURyjnNdPXAQkugbgFSbiyqyn-9ObIc0VOFF0JmlsgFXGMXSJp5uKCIaAnzIEALw_wcB&page=2&utm_adgroup=143959616297&utm_campaign=India_SEM_Brand_generic&utm_campaignid=1701551904&utm_content=751298002022&utm_device=c&utm_keyword=oyo&utm_medium=cpc&utm_source=google"
    print(f"Scraping page {page_num}")

    # 1. Send request
    response = requests.get(page_url,headers={"User-Agent": "Mozilla/5.0"})
    if response.status_code != 200:
        print(f"Page {page_num} not found. Stopping.")
        break

    soup = BeautifulSoup(response.content, "html.parser")
    hotels_card = soup.find_all('div',class_="oyo-cell--12-col oyo-cell--8-col-tablet oyo-cell--4-col-phone")


    for item in hotels_card:
        hotels=soup.find_all('div',class_="oyo-row oyo-row--no-spacing hotelCardListing")
        for hotel in hotels:
            title = hotel.h3["title"]
            Address=hotel.find('span',class_="u-line--clamp-2")["title"]
            num_rating=hotel.find('span',class_="hotelRating__ratingSummary hotelRating__rating--clickable").text
            star_rating=hotel.find('span',class_="is-fontBold hotelRating__rating hotelRating__rating--verygood hotelRating__rating--clickable")
            price=hotel.find('span',class_="listingPrice__finalPrice listingPrice__finalPrice--black").text
            #img_src = hotel.find("div", class_="c-ahj8kj").find("img")["src"]

            all_hotels_data.append({
                "title": title,
                "Address":Address,
                "num_rating":num_rating,
                "star_rating":star_rating,
                "price": price,
                #"img_src": img_src

            })

    time.sleep(1)
# Out:
# Scraping page 1
# Scraping page 2
# Scraping page 3
# Scraping page 4
# Scraping page 5

# %%
len(all_hotels_data)
# Out:
# 1980

# %%
all_hotels_data
# Out:
# [{'title': 'Collection O Silver Key Executive',
#   'Address': 'Perumbakkam, Chennai',
#   'num_rating': '(104 Ratings)',
#   'star_rating': None,
#   'price': '₹693'},
#  {'title': 'Super Hotel Redmoon Residency Elite',
#   'Address': 'Porur Chennai Tamilnadu-600116, Chennai',
#   'num_rating': '(427 Ratings)',
#   'star_rating': None,
#   'price': '₹1338'},
#  {'title': 'Hotel O Grand Residency',
#   'Address': 'Near By Kamatchi Hospital, kamakotti Nagar , Pallikaranai, Chennai.',
#   'num_rating': '(170 Ratings)',
#   'star_rating': <span class="is-fontBold hotelRating__rating hotelRating__rating--verygood hotelRating__rating--clickable"><span>4.2</span><span class="hotelRating__star"></span> </span>,
#   'price': '₹921'},
#  {'title': 'Super Collection O Kovur Formerly Kundrathur Residency',
#   'Address': 'Manacherry, Chennai',
#   'num_rating': '(65 Ratings)',
#   'star_rating': None,
#   'price': '₹1030'},
#  {'title': 'Super Hotel O Red Moon Residency ',
# ...

# %%
import pandas as pd
df=pd.DataFrame(all_hotels_data)
df.head()
# Out:
#                                                title  \
# 0                  Collection O Silver Key Executive
# 1                Super Hotel Redmoon Residency Elite
# 2                            Hotel O Grand Residency
# 3  Super Collection O Kovur Formerly Kundrathur R...
# 4                  Super Hotel O Red Moon Residency
#
#                                              Address     num_rating  \
# 0                               Perumbakkam, Chennai  (104 Ratings)
# 1            Porur Chennai Tamilnadu-600116, Chennai  (427 Ratings)
# 2  Near By Kamatchi Hospital, kamakotti Nagar , P...  (170 Ratings)
# 3                                Manacherry, Chennai   (65 Ratings)
# 4  5cross Street  pallavan nagar maduravoyal, Che...  (475 Ratings)
#
#       star_rating  price
# 0            None   ₹693
# 1            None  ₹1338
# 2  [[4.2], [],  ]   ₹921
# 3            None  ₹1030
# 4            None  ₹1411

# %%
df.drop_duplicates()
# Out:
#                                                   title  \
# 0                     Collection O Silver Key Executive
# 1                   Super Hotel Redmoon Residency Elite
# 2                               Hotel O Grand Residency
# 3     Super Collection O Kovur Formerly Kundrathur R...
# 4                     Super Hotel O Red Moon Residency
# 5                           Hotel O Karapakkam, Chennai
# 6                            Hotel O  Elite Grand hotel
# 7                              Hotel O Grand Pallavaram
# 8                   Super Hotel O J2 Service Appartment
# 9                               Hotel O Elite Residency
# 10    Collection O Madhavaram Botanical Garden Forme...
# 11                        SPOT ON Eswar Grand Residency
# 12                                  Hotel O Kelambakkam
# 13           Townhouse Nanganallur Near Chennai Airport
# 14    Hotel O Kelambakkam Bus Terminal Formerly Guna...
# 15                                Collection O Yash Inn
# ...

# %%
df.shape
# Out:
# (1980, 5)
